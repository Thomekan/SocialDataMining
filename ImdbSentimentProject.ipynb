# %%
#Importing relevant libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from time import sleep
from random import randint
import numpy as np
import feedparser
from nltk.corpus import stopwords
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from pymongo import MongoClient
import json
import sys
import certifi

#import OAuth #-- this is a module where I keep my connection string with secret passwords and authentication. You'll have to make yours

# %%
#Assigning columns to pandas dataframe
tag = []      #The unique movie tag from IMDB
titles = []   #Movie titles/names
years = []    #Year movie was released
time = []     #The length of movie run time
rating = []    #Ratings on IMDB
genre = []    #Genre(s) of movie
votes = []    #Number of votes on movie title
link = []     #URL link to movie's IMDB web page
image = []    #URL link to movie poster
review = []   #Reviews for each movie

# %%
#Setting headers to match browser type
headers = dict()
headers[
    "User-Agent"
] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"

#setting the number of pages to be scraped using numpy
#Two pages are needed to get the first 100 movies
pages = np.arange(1, 101, 50)

#Assigning url link and iterating scraping code over pages
for page in pages:
    url = "https://www.imdb.com/search/title/?groups=top_1000&start=" + str(page)
    results = requests.get(url, headers=headers)
    soup = BeautifulSoup(results.text, "html.parser")
    movie_div = soup.find_all("div", class_="lister-item mode-advanced")
    sleep(randint(2, 10))
    #print(page)

# %%
    #iterating scraping code over each section in the webpage
    for movieSection in movie_div:
        name = movieSection.h3.a.text
        titles.append(name)

        year = movieSection.h3.find("span", class_="lister-item-year").text
        years.append(year)

        runTime = movieSection.find("span", class_="runtime").text
        time.append(runTime) 

        ratings = movieSection.strong.text
        rating.append(ratings)

        category = movieSection.find("span", class_="genre").text.strip()
        genre.append(category)

        nv = movieSection.find_all("span", attrs={"name": "nv"})
        vote = nv[0].text
        votes.append(vote)

        links = "https://www.imdb.com" + movieSection.a.attrs['href']
        link.append(links)

        thumbs = movieSection.img.attrs['loadlate']
        images = thumbs.replace("._V1_UX67_CR0,0,67,98_AL_.jpg", "._V1_FMjpg_UX1000_.jpg")
        image.append(images)
        
        tagg = links.replace("https://www.imdb.com/title/", "")
        tags = tagg.replace("/?ref_=adv_li_i", "")
        tag.append(tags)
        


            #getting reviews for each movie link
    for l in link:
        rev = l.replace("?ref_=adv_li_i", "reviews?ref_=tt_ov_rt")
        response = requests.get(rev, headers=headers)
        stew = BeautifulSoup(response.text, "html.parser")
        content = stew.find_all('div', class_=['text','show-more__control'])
        #print(rev)

        reviews = [tag.get_text() for tag in content]
        review.append(reviews[:5])

#print (review[:5])

# %%
#Saving to a dataframe called movie
movie = pd.DataFrame(
    {
        "UniqueTags": tag,
        "Movie": titles,
        "Year": years,
        "RunTime": time,
        "imdb": rating,
        "Genre": genre,
        "votes": votes,
        "URL": link,
        "ImageLinks": image,
        "Reviews": review,
    }
)

# %%
#printing dataframe to console
print(movie)
# Out:
#    UniqueTags                                              Movie         Year  \
# 0   tt0108358                                          Tombstone       (1993)
# 1   tt2543164                                            Arrival  (II) (2016)
# 2   tt8503618                                           Hamilton       (2020)
# 3   tt0119217                                  Good Will Hunting       (1997)
# 4   tt3281548                                       Little Women       (2019)
# 5   tt3501632                                     Thor: Ragnarok       (2017)
# 6   tt8367814                                      The Gentlemen       (2019)
# 7   tt0075314                                        Taxi Driver       (1976)
# 8   tt0144084                                    American Psycho       (2000)
# 9   tt0106677                                 Dazed and Confused       (1993)
# 10  tt0137523                                         Fight Club       (1999)
# 11  tt0114369                                              Se7en       (1995)
# 12  tt0083658                                       Blade Runner       (1982)
# 13  tt1345836                              The Dark Knight Rises       (2012)
# 14  tt0477348                             No Country for Old Men       (2007)
# 15  tt5463162                                         Deadpool 2       (2018)
# 16  tt1201607       Harry Potter and the Deathly Hallows: Part 2       (2011)
# 17  tt0088763                                 Back to the Future       (1985)
# 18  tt0095016                                           Die Hard       (1988)
# 19  tt5726616                               Call Me by Your Name       (2017)
# 20  tt5052448                                            Get Out   (I) (2017)
# 21  tt1663202                                       The Revenant       (2015)
# 22  tt0081505                                        The Shining       (1980)
# 23  tt0120689                                     The Green Mile       (1999)
# 24  tt0108052                                   Schindler's List       (1993)
# 25  tt2582802                                           Whiplash       (2014)
# 26  tt4633694                  Spider-Man: Into the Spider-Verse       (2018)
# 27  tt0330373                Harry Potter and the Goblet of Fire       (2005)
# 28  tt0078748                                              Alien       (1979)
# 29  tt1596363                                      The Big Short       (2015)
# 30  tt3890160                                        Baby Driver       (2017)
# 31  tt0093779                                 The Princess Bride       (1987)
# 32  tt0325980  Pirates of the Caribbean: The Curse of the Bla...       (2003)
# 33  tt3315342                                              Logan       (2017)
# 34  tt0172495                                          Gladiator       (2000)
# 35  tt0499549                                             Avatar       (2009)
# 36  tt0061722                                       The Graduate       (1967)
# 37  tt2584384                                        Jojo Rabbit       (2019)
# 38  tt0482571                                       The Prestige       (2006)
# 39  tt0167260      The Lord of the Rings: The Return of the King       (2003)
# 40  tt0110413                                               Léon       (1994)
# 41  tt0060196                    Il buono, il brutto, il cattivo       (1966)
# 42  tt0372784                                      Batman Begins       (2005)
# 43  tt1130884                                     Shutter Island       (2010)
# 44  tt0470752                                         Ex Machina       (2014)
# 45  tt0371746                                           Iron Man       (2008)
# 46  tt1454029                                           The Help       (2011)
# 47  tt2278388                           The Grand Budapest Hotel       (2014)
# 48  tt0050083                                       12 Angry Men       (1957)
# 49  tt3416742                          What We Do in the Shadows       (2014)
#
#     RunTime imdb                         Genre      votes  \
# 0   130 min  7.8      Action, Biography, Drama    136,206
# 1   116 min  7.9                 Drama, Sci-Fi    634,923
# 2   160 min  8.4     Biography, Drama, History     74,102
# 3   126 min  8.3                Drama, Romance    901,714
# 4   135 min  7.8                Drama, Romance    166,035
# 5   130 min  7.9     Action, Adventure, Comedy    647,895
# 6   113 min  7.8         Action, Comedy, Crime    282,157
# 7   114 min  8.2                  Crime, Drama    762,556
# 8   101 min  7.6          Comedy, Crime, Drama    526,287
# 9   102 min  7.6                        Comedy    174,161
# 10  139 min  8.8                         Drama  1,942,628
# 11  127 min  8.6         Crime, Drama, Mystery  1,518,655
# 12  117 min  8.1      Action, Sci-Fi, Thriller    722,651
# 13  164 min  8.4                        Action  1,579,690
# 14  122 min  8.1        Crime, Drama, Thriller    901,808
# 15  119 min  7.7     Action, Adventure, Comedy    518,570
# 16  130 min  8.1   Adventure, Fantasy, Mystery    803,568
# 17  116 min  8.5     Adventure, Comedy, Sci-Fi  1,114,298
# 18  132 min  8.2              Action, Thriller    821,371
# 19  132 min  7.9                Drama, Romance    236,795
# 20  104 min  7.7     Horror, Mystery, Thriller    531,204
# 21  156 min  8.0      Action, Adventure, Drama    742,903
# 41  [A sprawling Western epic that follows the adv...
# 42  [To tell the truth, I thought the Batman franc...
# 43  [I know there is already a spoiler warning up ...
# 44  [This movie is obviously allegorical, a fascin...
# 45  [In my attempt to rewatch all the MCU-movies c...
# 46  [If this film were total fiction bearing no re...
# 47  [Can a film be absurd, funny, exciting, violen...
# 48  [The only thing I can write as an average Joe ...
# 49  [Lot's of people are disregarding this movie d...

# %%
#Cleaning the dataframe

#Removing brackets and converting from text to number
movie["Year"] = movie["Year"].str.extract("(\\d+)").astype(int)

#Changing min to minutes
movie["RunTime"] = movie["RunTime"].str.replace("min", "minutes")

#Converting votes from text to numbers and removing commas
movie["votes"] = movie["votes"].str.replace(",", "").astype(int)


movie.head()
# Out:
#   UniqueTags              Movie  Year      RunTime imdb  \
# 0  tt0108358          Tombstone  1993  130 minutes  7.8
# 1  tt2543164            Arrival  2016  116 minutes  7.9
# 2  tt8503618           Hamilton  2020  160 minutes  8.4
# 3  tt0119217  Good Will Hunting  1997  126 minutes  8.3
# 4  tt3281548       Little Women  2019  135 minutes  7.8
#
#                        Genre   votes  \
# 0   Action, Biography, Drama  136206
# 1              Drama, Sci-Fi  634923
# 2  Biography, Drama, History   74102
# 3             Drama, Romance  901714
# 4             Drama, Romance  166035
#
#                                                  URL  \
# 0  https://www.imdb.com/title/tt0108358/?ref_=adv...
# 1  https://www.imdb.com/title/tt2543164/?ref_=adv...
# 2  https://www.imdb.com/title/tt8503618/?ref_=adv...
# 3  https://www.imdb.com/title/tt0119217/?ref_=adv...
# 4  https://www.imdb.com/title/tt3281548/?ref_=adv...
#
#                                           ImageLinks  \
# 0  https://m.media-amazon.com/images/M/MV5BODRkYz...
# 1  https://m.media-amazon.com/images/M/MV5BMTExMz...
# 2  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 3  https://m.media-amazon.com/images/M/MV5BOTI0Mz...
# 4  https://m.media-amazon.com/images/M/MV5BY2QzYT...
#
#                                              Reviews
# 0  [I wont review the film here as it has all bee...
# 1  ["I used to think this was the beginning of yo...
# 2  [I mean, i WAS pretty high, but still.It defin...
# 3  [Sure, this film's plot is fairly predictable....
# 4  [Some comments lament the movie has changed fr...

# %%
#Converting column from list to string
movie['Reviews'] = movie['Reviews'].apply(', '.join)

# %%
#Deleting Punctuations from Column
movie['Reviews'] = movie['Reviews'].str.replace('[^\w\s]','')
# Out:
# <ipython-input-10-73fe569b1fac>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   movie['Reviews'] = movie['Reviews'].str.replace('[^\w\s]','')

# %%
#Deleting stop Words
stop = stopwords.words('english')
movie['Reviews']= movie['Reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
#Ensures each row in column has a minimum of 3 words
movie= movie[movie['Reviews'].str.len()>3]

# %%
#Convert to lowercase
movie['Reviews']= movie['Reviews'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
#Dataframe head to console
movie.head()
# Out:
#   UniqueTags              Movie  Year      RunTime imdb  \
# 0  tt0108358          Tombstone  1993  130 minutes  7.8
# 1  tt2543164            Arrival  2016  116 minutes  7.9
# 2  tt8503618           Hamilton  2020  160 minutes  8.4
# 3  tt0119217  Good Will Hunting  1997  126 minutes  8.3
# 4  tt3281548       Little Women  2019  135 minutes  7.8
#
#                        Genre   votes  \
# 0   Action, Biography, Drama  136206
# 1              Drama, Sci-Fi  634923
# 2  Biography, Drama, History   74102
# 3             Drama, Romance  901714
# 4             Drama, Romance  166035
#
#                                                  URL  \
# 0  https://www.imdb.com/title/tt0108358/?ref_=adv...
# 1  https://www.imdb.com/title/tt2543164/?ref_=adv...
# 2  https://www.imdb.com/title/tt8503618/?ref_=adv...
# 3  https://www.imdb.com/title/tt0119217/?ref_=adv...
# 4  https://www.imdb.com/title/tt3281548/?ref_=adv...
#
#                                           ImageLinks  \
# 0  https://m.media-amazon.com/images/M/MV5BODRkYz...
# 1  https://m.media-amazon.com/images/M/MV5BMTExMz...
# 2  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 3  https://m.media-amazon.com/images/M/MV5BOTI0Mz...
# 4  https://m.media-amazon.com/images/M/MV5BY2QzYT...
#
#                                              Reviews
# 0  i wont review film said i want praise val kilm...
# 1  i used think beginning story were bound time d...
# 2  i mean was pretty high stillit definitely live...
# 3  sure films plot fairly predictable sure boiled...
# 4  some comments lament movie changed book especi...

# %%
#Saving to a csv file on local disk
#movies.to_csv(r"C:\Users\dtosi\Downloads\movies_.csv", index=False, header=True)

# %%
#Calculating polarity scores for each entry
analyzer = SentimentIntensityAnalyzer()
emptyline = []
for row in movie['Reviews']:
    ps = analyzer.polarity_scores(row)
    emptyline.append(ps)

# %%
#Creating a dataframe for the sentiments data
df_sentiments = pd.DataFrame(emptyline)
df_sentiments.head()
# Out:
#      neg    neu    pos  compound
# 0  0.093  0.595  0.312    0.9988
# 1  0.068  0.727  0.205    0.9974
# 2  0.000  0.586  0.414    0.9729
# 3  0.149  0.589  0.262    0.9933
# 4  0.077  0.722  0.201    0.9879

# %%
#Merging main data frame and sentiment data frame
df_join = pd.concat([movie.reset_index(drop = True), df_sentiments], axis=1)
df_join.head(5)
# Out:
#   UniqueTags              Movie  Year      RunTime imdb  \
# 0  tt0108358          Tombstone  1993  130 minutes  7.8
# 1  tt2543164            Arrival  2016  116 minutes  7.9
# 2  tt8503618           Hamilton  2020  160 minutes  8.4
# 3  tt0119217  Good Will Hunting  1997  126 minutes  8.3
# 4  tt3281548       Little Women  2019  135 minutes  7.8
#
#                        Genre   votes  \
# 0   Action, Biography, Drama  136206
# 1              Drama, Sci-Fi  634923
# 2  Biography, Drama, History   74102
# 3             Drama, Romance  901714
# 4             Drama, Romance  166035
#
#                                                  URL  \
# 0  https://www.imdb.com/title/tt0108358/?ref_=adv...
# 1  https://www.imdb.com/title/tt2543164/?ref_=adv...
# 2  https://www.imdb.com/title/tt8503618/?ref_=adv...
# 3  https://www.imdb.com/title/tt0119217/?ref_=adv...
# 4  https://www.imdb.com/title/tt3281548/?ref_=adv...
#
#                                           ImageLinks  \
# 0  https://m.media-amazon.com/images/M/MV5BODRkYz...
# 1  https://m.media-amazon.com/images/M/MV5BMTExMz...
# 2  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 3  https://m.media-amazon.com/images/M/MV5BOTI0Mz...
# 4  https://m.media-amazon.com/images/M/MV5BY2QzYT...
#
#                                              Reviews    neg    neu    pos  \
# 0  i wont review film said i want praise val kilm...  0.093  0.595  0.312
# 1  i used think beginning story were bound time d...  0.068  0.727  0.205
# 2  i mean was pretty high stillit definitely live...  0.000  0.586  0.414
# 3  sure films plot fairly predictable sure boiled...  0.149  0.589  0.262
# 4  some comments lament movie changed book especi...  0.077  0.722  0.201
#
#    compound
# 0    0.9988
# 1    0.9974
# 2    0.9729
# 3    0.9933
# 4    0.9879

# %%
#Populating sentiment field and words field
df_join['sentiment'] = df_join['compound'].apply(lambda score: 'positive' if score > 0.01 else 'negative')
df_join['words'] = df_join['Reviews'].apply(lambda lst: lst.split(" "))
df_join.head(5)
# Out:
#   UniqueTags              Movie  Year      RunTime imdb  \
# 0  tt0108358          Tombstone  1993  130 minutes  7.8
# 1  tt2543164            Arrival  2016  116 minutes  7.9
# 2  tt8503618           Hamilton  2020  160 minutes  8.4
# 3  tt0119217  Good Will Hunting  1997  126 minutes  8.3
# 4  tt3281548       Little Women  2019  135 minutes  7.8
#
#                        Genre   votes  \
# 0   Action, Biography, Drama  136206
# 1              Drama, Sci-Fi  634923
# 2  Biography, Drama, History   74102
# 3             Drama, Romance  901714
# 4             Drama, Romance  166035
#
#                                                  URL  \
# 0  https://www.imdb.com/title/tt0108358/?ref_=adv...
# 1  https://www.imdb.com/title/tt2543164/?ref_=adv...
# 2  https://www.imdb.com/title/tt8503618/?ref_=adv...
# 3  https://www.imdb.com/title/tt0119217/?ref_=adv...
# 4  https://www.imdb.com/title/tt3281548/?ref_=adv...
#
#                                           ImageLinks  \
# 0  https://m.media-amazon.com/images/M/MV5BODRkYz...
# 1  https://m.media-amazon.com/images/M/MV5BMTExMz...
# 2  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 3  https://m.media-amazon.com/images/M/MV5BOTI0Mz...
# 4  https://m.media-amazon.com/images/M/MV5BY2QzYT...
#
#                                              Reviews    neg    neu    pos  \
# 0  i wont review film said i want praise val kilm...  0.093  0.595  0.312
# 1  i used think beginning story were bound time d...  0.068  0.727  0.205
# 2  i mean was pretty high stillit definitely live...  0.000  0.586  0.414
# 3  sure films plot fairly predictable sure boiled...  0.149  0.589  0.262
# 4  some comments lament movie changed book especi...  0.077  0.722  0.201
#
#    compound sentiment                                              words
# 0    0.9988  positive  [i, wont, review, film, said, i, want, praise,...
# 1    0.9974  positive  [i, used, think, beginning, story, were, bound...
# 2    0.9729  positive  [i, mean, was, pretty, high, stillit, definite...
# 3    0.9933  positive  [sure, films, plot, fairly, predictable, sure,...
# 4    0.9879  positive  [some, comments, lament, movie, changed, book,...

# %%
#Saving to database. Here I use MongoDB (I find it very convinient, friendly and interesting), you could also use any database management system that suites you.

#MongoDB connection and authenication
ca = certifi.where() #certificates

client = MongoClient("mongodb+srv://et:1234@sdmt.ddltj.mongodb.net/myFirstDatabase?retryWrites=true&w=majority", tlsCAFile=ca) #dbSvr in the module OAuth is my database server address in MongoDB
db = client['sentiment'] #'sentiment' is the name I chose for the database
collection = db.imdb

# %%
#Now we convert our data to dictionary format for ease in JSON format. You do not have to save
#in JSON format or dictionaries. Mongo DB is versatile and can work with flat data frames.
df_join.reset_index(drop = True, inplace = True)
data_dict = df_join.to_dict("records")

# %%
#Now we upload to Mongo
collection.insert_many(data_dict)
#collection.insert_one(df_join)

# %%
#I continued my visualization on Tableau. You can see my vizzes on
